# %%
#Imports
import os
from os import system
import pycharmm
import pycharmm.lib as lib
import pycharmm.read as read
import pycharmm.lingo as lingo
import pycharmm.settings as settings

# %%
settings.set_bomb_level(-1)
read.rtf('"/home/trowray/acrb/toppar/top_all36_prot.rtf"')
read.rtf('"/home/trowray/acrb/toppar/top_all36_cgenff.rtf"', append = True)
read.prm('"/home/trowray/acrb/toppar/par_all36m_prot.prm"', flex = True)
read.prm('"/home/trowray/acrb/toppar/par_all36_cgenff.prm"', append = True, flex = True)
settings.set_bomb_level(0)
lingo.charmm_script('stream "/home/trowray/acrb/ligand_rtf/5qe.rtf"')
# Out:
# [1656444261.740414] [gollum:30417:0]    ucp_context.c:1131 UCX  WARN  UCP version is incompatible, required: 1.5, actual: 1.4 (release 0)
# [1656444261.884178] [gollum:30417:0]    ucp_context.c:1131 UCX  WARN  UCP version is incompatible, required: 1.5, actual: 1.4 (release 0)
#
#  CHARMM>     read rtf card -
#  CHARMM>     name "/home/trowray/acrb/toppar/top_all36_prot.rtf"
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/top_all36_prot.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *>>>>>>>>CHARMM36 ALL-HYDROGEN TOPOLOGY FILE FOR PROTEINS <<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> MAY 2011 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name "/home/trowray/acrb/toppar/top_all36_cgenff.rtf" -
#  CHARMM>     append
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/top_all36_cgenff.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name "/home/trowray/acrb/toppar/par_all36m_prot.prm" -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/par_all36m_prot.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name "/home/trowray/acrb/toppar/par_all36_cgenff.prm" -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/par_all36_cgenff.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L CLGR   -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  CLGR   -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L BRGR   -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL  BRGR   -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  CLGR   -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G CLGR   -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  CLGR   -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C CLGR   -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1  BRGR   -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2  BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G BRGR   -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4  BRGR   -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1  BRGR   -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C BRGR   -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     stream "/home/trowray/acrb/ligand_rtf/5qe.rtf"
#  VOPEN> Attempting to open::/home/trowray/acrb/ligand_rtf/5qe.rtf::
#  OPNLGU> Unit 99 opened for READONLY access to /home/trowray/acrb/ligand_rtf/5qe.rtf
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.6
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
# 1

# %%
from pycharmm.cdocker import Rigid_CDOCKER
help(Rigid_CDOCKER)
# Out:
# Help on function Rigid_CDOCKER in module pycharmm.cdocker:
#
# Rigid_CDOCKER(xcen=0, ycen=0, zcen=0, maxlen=10, dielec=3, rcta=0, rctb=0, hmax=0, flag_grid=False, flag_rdie=True, flag_form=False, flag_delete_grid=True, probeFile='"../Toppar/fftdock_c36prot_cgenff_probes.txt"', softGridFile='grid-emax-0.6-mine--0.4-maxe-0.4.bin', hardGridFile='grid-emax-3-mine--30-maxe-30.bin', nativeGridFile='grid-emax-100-mine--100-maxe-100.bin', receptorPDB='./protein.pdb', receptorPSF='./protein.psf', ligPDB='./ligand.pdb', ligSeg='LIGA', confDir='./conformer/', placementDir='./placement/', exhaustiveness='high', numPlace=100, numCopy=1000, flag_delete_conformer=True, flag_delete_placement=True, flag_save_all=True, flag_save_cluster=True, flag_save_top=True, flag_suppress_print=True, flag_center_ligand=True, flag_fast_grid=False, flag_use_hbond=False, flag_fast_placement=True, threshold=2500, sort_energy='total_energy', saveDir='./dockresult/')
#     Rigid CDOCKER standard docking method
#
#     Parameters
#     ----------
#     xcen: float
#            center of the docking pocket
#     ycen: float
#            center of the docking pocket
#     zcen: float
#            center of the docking pocket
#     maxlen: float
#              size of the grid box
#     dielec: float
#              dielectric constant
#     rcta: float
#            customizable grid left cutoff
#     rctb: float
#            customizable grid right cutoff
#     hmax: float
#            customizable grid well-depth
#     flag_grid: bool
#                 whether or not grid need to be generated
#     flag_rdie: bool
#                 true for rdie, false for cdie
#     flag_form: bool
#                 whether or not grid form is formatted
#     flag_delete_grid: bool
#                        whether or not delete grid after calculation
#     probeFile: str
#                 gpu probe file names
#     softGridFile: str
#                    soft grid file name
#     hardGridFile: str
#                    hard grid file name
#     nativeGridFile: str
#                      native grid file name
#     receptorPDB: str
#               protein pdb file name
#     receptorPSF: str
#               protein psf file name
#     ligPDB: str
#              ligand pdb file name
#     ligSeg: str
#              ligand segment ID
#     confDir: str
#               conformer folder name
#     placementDir: str
#                    placement folder name
#     exhaustiveness: str
#                      exhaustiveness for fast placement, high, medium, low
#     numPlace: int
#                number of placement for each conformer
#     numCopy: int
#               number of Copy for OpenMM docking simulated annealing
#     flag_delete_conformer: bool
#                             whether or not delete conformer after docking
#     flag_delete_placement: bool
#                             whether or not delete placement after docking
#     flag_save_all: bool
#                     whether or not save all docked pose
#     flag_save_cluster: bool
#                         whether or not save clustered results
#     flag_save_top: bool
#                     whether or not save top 10 lowest energy pose
#     flag_suppress_print: bool
#                           whether or not suppress printing
#     flag_fast_grid: bool
#                      whether or not just use grid minimize result i.e., skip all atom mini
#     flag_center_ligand: bool
#                          whether or not ligand need to be centered
#     flag_use_hbond : bool
#                      whether or not use hydrogen/covalent bond in RCDOCKER
#     flag_fast_placement : bool
#                           whether or not use fast placement
#     threshold : float
#                 cutoff threshold for original RCDOCKER placement
#                 only meaningful when flag_fast_placement = True
#     sort_energy: str
#                   sorting method
#     saveDir: str
#               folder name for docked result
#
#     Returns
#     -------
#     pd.DataFrame clusterResult: clustering result
#     pd.DataFrame dockResult: docking result

# %%
## Copy grid files
os.system('cp /home/trowray/pycharmm-workshop/cdocker_wyu/jupyter_lab/grid/rigid/* /home/trowray/acrb/')
# Out:
# 0

# %%
## Import module
import numpy as np
import pycharmm
import pycharmm.lib as lib
import pycharmm.read as read
import pycharmm.lingo as lingo
import pycharmm.settings as settings
import pycharmm.generate as gen
import pycharmm.coor as coor
from pycharmm.cdocker import Rigid_CDOCKER

## File name and pathway
ligPDB = "/home/trowray/acrb/ligand_pdb/5qe.pdb"
ligandrtf = "/home/trowray/acrb/ligand_rtf/5qe.rtf"
confDir = "/home/trowray/acrb/ligand_conf/"
receptorPDB = "/home/trowray/acrb/pdb/1iwg.pdb"
receptorPSF = "/home/trowray/acrb/pdb/1iwg.psf"

## Build ligand and find grid box dimension
read.sequence_pdb(ligPDB)
gen.new_segment(seg_name = "LIGA")
read.pdb(ligPDB, resid = True)
coorStat = coor.stat()

xcen = coorStat.get('xave')
ycen = coorStat.get('yave')
zcen = coorStat.get('zave')

xlen = coorStat.get('xmax') - coorStat.get('xmin')
ylen = coorStat.get('ymax') - coorStat.get('ymin')
zlen = coorStat.get('zmax') - coorStat.get('zmin')

tmp = np.array([xlen, ylen, zlen])
maxlen = np.amax(tmp) + 10

## Topology and parameter files
settings.set_bomb_level(-1)
read.rtf('"/home/trowray/acrb/toppar/top_all36_prot.rtf"')
read.rtf('"/home/trowray/acrb/toppar/top_all36_cgenff.rtf"', append = True)
read.prm('"/home/trowray/acrb/toppar/par_all36m_prot.prm"', flex = True)
read.prm('"/home/trowray/acrb/toppar/par_all36_cgenff.prm"', append = True, flex = True)
settings.set_bomb_level(0)
lingo.charmm_script('stream "/home/trowray/acrb/ligand_rtf/5qe.rtf"')

## Rigid CDOCKER standard docking protocol
clusterResult, dockResult = Rigid_CDOCKER(xcen = xcen, ycen = ycen, zcen = zcen,
                                        maxlen = maxlen, ligPDB = ligPDB, receptorPDB = receptorPDB,
                                        receptorPSF = receptorPSF, confDir = confDir, flag_grid = True,
                                        flag_delete_conformer = False, flag_fast_placement = False)

print(clusterResult)
print(dockResult)
exit()
# Out:
#
#  CHARMM>     read sequence pdb -
#  CHARMM>     name /home/trowray/acrb/ligand_pdb/5qe.pdb
#  VOPEN> Attempting to open::/home/trowray/acrb/ligand_pdb/5qe.pdb::
#  MAINIO> Sequence information being read from unit  91.
#  TITLE>  *
#
#           RESIDUE SEQUENCE --     1 RESIDUES
#           5QE
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  AUTGEN: Autogenerating specified angles and dihedrals.
#  CHECKDH> dihedral with linear angles:    2    1    3    4 will NOT be generated
#  CHECKDH> dihedral with linear angles:    2    1    3    9 will NOT be generated
#  GENPSF> Segment   1 has been generated. Its identifier is LIGA.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =        1
#          Number of atoms         =       69   Number of groups     =        1
#          Number of bonds         =       72   Number of angles     =      131
#          Number of dihedrals     =      181   Number of impropers  =        2
#          Number of cross-terms   =        0   Number of autogens   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =    0.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name /home/trowray/acrb/ligand_pdb/5qe.pdb -
#  CHARMM>     resid
#  VOPEN> Attempting to open::/home/trowray/acrb/ligand_pdb/5qe.pdb::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name "/home/trowray/acrb/toppar/top_all36_prot.rtf"
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/top_all36_prot.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *>>>>>>>>CHARMM36 ALL-HYDROGEN TOPOLOGY FILE FOR PROTEINS <<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> MAY 2011 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read rtf card -
#  CHARMM>     name "/home/trowray/acrb/toppar/top_all36_cgenff.rtf" -
#  CHARMM>     append
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/top_all36_cgenff.rtf::
#  MAINIO> Residue topology file being read from unit  91.
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *          CGENFF: TOPOLOGY FOR THE CHARMM GENERAL FORCE FIELD V. 4.6          *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *
#
#  DRUDES PARTICLES WILL BE GENERATED AUTOMATICALLY FOR ALL ATOMS WITH NON-ZERO ALPHA
#  Thole-type dipole screening, Slater-Delta shape {S(u) = 1 - (1+u/2)*exp(-u)}, default radius =  1.300000
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name "/home/trowray/acrb/toppar/par_all36m_prot.prm" -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/par_all36m_prot.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *>>>> CHARMM36 ALL-HYDROGEN PARAMETER FILE FOR PROTEINS <<<<<<<<<<
#  TITLE> *>>>>> INCLUDES PHI, PSI CROSS TERM MAP (CMAP) CORRECTION <<<<<<<<
#  TITLE> *>>>>>>>>>>>>>>>>>>>>>>>>>> JAN. 2016 <<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  TITLE> * ALL COMMENTS TO THE CHARMM WEB SITE: WWW.CHARMM.ORG
#  TITLE> *             PARAMETER SET DISCUSSION FORUM
#  TITLE> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     read param card -
#  CHARMM>     name "/home/trowray/acrb/toppar/par_all36_cgenff.prm" -
#  CHARMM>     append -
#  CHARMM>     flex
#  VOPEN> Attempting to open::/home/trowray/acrb/toppar/par_all36_cgenff.prm::
#
#           PARAMETER FILE BEING READ FROM UNIT 91
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *         CGENFF: PARAMETERS FOR THE CHARMM GENERAL FORCE FIELD V. 4.6         *
#  TITLE> *                    FOR SMALL MOLECULE DRUG DESIGN                            *
#  TITLE> *  --------------------------------------------------------------------------  *
#  TITLE> *  2017/8: IF PROTEIN, NUCLEIC ACID AND CARBOHYDRATE TOPOLOGY AND PARAMETER FILES
#  TITLE> *  ARE NOT READ PRIOR TO THE CGENFF FILES "WARNING: ATOMS IN NBFIX ' errors will
#  TITLE> *  BE ENCOUNTERED.  THESE CAN BE PASSED BY SETTING BOMLEV ( -2) PRIOR TO READING
#  TITLE> *  THIS FILE. IN ADDITION, WHEN GENERATING AROMATIC HALOGENS (CL, BR, I) WITH
#  TITLE> *  PRE C41B/C42A VERSIONS OF CHARMM "MISSING PARAMETER" ERRORS WILL BE
#  TITLE> *  ENCOUNTERED THAT ALSO REQUIRE SETTING BOMLEV ( -2).
#  TITLE> *
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D1    CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D2    CLGR1      -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D3    CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D4    CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D2    BRGR1      -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D3    BRGR1      -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OC2D4    BRGR1      -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL      CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L     CLGR1      -3.60000   3.18000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL      CLGR1      -2.50000   2.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OBL      BRGR1      -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NH3L     BRGR1      -3.65000   3.33000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX OCL      BRGR1      -1.25000   2.98000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1      CLGR1      -0.40000   3.88000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2      CLGR1      -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U     CLGR1      -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G     CLGR1      -0.48000   3.75000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3      CLGR1      -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A     CLGR1      -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G     CLGR1      -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4      CLGR1      -0.46000   3.42000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1      CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C     CLGR1      -0.20000   3.40000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN1      BRGR1      -0.30000   4.05000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2      BRGR1      -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2U     BRGR1      -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN2G     BRGR1      -0.72000   3.80000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3      BRGR1      -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3A     BRGR1      -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN3G     BRGR1      -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX NN4      BRGR1      -0.22000   3.61000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1      BRGR1      -0.27000   3.52000 DONT EXIST
#
#       ***** LEVEL  0 WARNING FROM <PARRDR> *****
#       ***** NO MATCH FOR NBFIX
#       ******************************************
#       BOMLEV ( -1) IS NOT REACHED. WRNLEV IS  5
#
#  PARRDR> WARNING: ATOMS IN NBFIX ON1C     BRGR1      -0.27000   3.52000 DONT EXIST
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     stream "/home/trowray/acrb/ligand_rtf/5qe.rtf"
#  VOPEN> Attempting to open::/home/trowray/acrb/ligand_rtf/5qe.rtf::
#  OPNLGU> Unit 99 opened for READONLY access to /home/trowray/acrb/ligand_rtf/5qe.rtf
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.6
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#
#       ***** LEVEL  1 WARNING FROM <rtfrdr> *****
#       ***** No AUTOgen defaults specified in appended RTF. Potential conflict with prior RTF autogen options. Check.
#       ******************************************
#       BOMLEV (  0) IS NOT REACHED. WRNLEV IS  5
#
#
#  CHARMM>
#
#  CHARMM>    read param card flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
#
#  *** LEVEL  1 WARNING *** BOMLEV IS   -1
#  *** LEVEL  1 WARNING *** BOMLEV IS   -1
#  *** LEVEL  1 WARNING *** BOMLEV IS   -1
#  *** LEVEL  1 WARNING *** BOMLEV IS   -1
#
#  CHARMM>     update atom -
#  CHARMM>     switch -
#  CHARMM>     vswitch -
#  CHARMM>     vdwe -
#  CHARMM>     elec -
#  CHARMM>     rdie -
#  CHARMM>     cutnb 12 -
#  CHARMM>     ctofnb 10 -
#  CHARMM>     ctonnb 8 -
#  CHARMM>     emax 10000 -
#  CHARMM>     maxe 10000 -
#  CHARMM>     mine -10000 -
#  CHARMM>     epsilon 3
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    RDIElec  SWITch   VATOm    VSWItch
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 12.000 CTEXNB =999.000 CTONNB =  8.000 CTOFNB = 10.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  3.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found    203 exclusions and    171 interactions(1-4)
#  <MAKGRP> found      0 group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR     2347 ATOM PAIRS AND        0 GROUP PAIRS
#  NBONDA>>  Maximum group spatial extent (12A) exceeded.
#    Size is       14.79 Angstroms and starts with atom:       1
#    Please check group boundary definitions.
#
#  General atom nonbond list generation found:
#      1952 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         1 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#
#  CHARMM>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/trowray/acrb/acrb_docking.ipynb Cell 5' in <cell line: 46>()
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=42'>43</a> lingo.charmm_script('stream "/home/trowray/acrb/ligand_rtf/5qe.rtf"')
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=44'>45</a> ## Rigid CDOCKER standard docking protocol
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=45'>46</a> clusterResult, dockResult = Rigid_CDOCKER(xcen = xcen, ycen = ycen, zcen = zcen,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=46'>47</a>                                         maxlen = maxlen, ligPDB = ligPDB, receptorPDB = receptorPDB,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=47'>48</a>                                         receptorPSF = receptorPSF, confDir = confDir, flag_grid = True,
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=48'>49</a>                                         flag_delete_conformer = False, numPlace = 5)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=50'>51</a> print(clusterResult)
#      <a href='vscode-notebook-cell://ssh-remote%2Bgollum/home/trowray/acrb/acrb_docking.ipynb#ch0000003vscode-remote?line=51'>52</a> print(dockResult)
#
# File /export/apps/CentOS7/anaconda/2022/envs/pycharmm-0.5/lib/python3.8/site-packages/pycharmm/cdocker.py:1706, in Rigid_CDOCKER(xcen, ycen, zcen, maxlen, dielec, rcta, rctb, hmax, flag_grid, flag_rdie, flag_form, flag_delete_grid, probeFile, softGridFile, hardGridFile, nativeGridFile, receptorPDB, receptorPSF, ligPDB, ligSeg, confDir, placementDir, exhaustiveness, numPlace, numCopy, flag_delete_conformer, flag_delete_placement, flag_save_all, flag_save_cluster, flag_save_top, flag_suppress_print, flag_center_ligand, flag_fast_grid, flag_use_hbond, flag_fast_placement, threshold, sort_energy, saveDir)
#    1704 dockResult = dockResult.sort_values(by = ["total_energy"], ignore_index = True)
#    1705 dockResult.to_csv(saveDir + 'dockResult.tsv', sep = '	')
# -> 1706 clusterResult = clusterResult.sort_values(by = ["total_energy"], ignore_index = True)
#    1707 clusterResult.to_csv(saveDir + 'clusterResult.tsv', sep = '	')
#    1709 ## Explicit atom minimization
#
# File /export/apps/CentOS7/anaconda/2022/envs/pycharmm-0.5/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /export/apps/CentOS7/anaconda/2022/envs/pycharmm-0.5/lib/python3.8/site-packages/pandas/core/frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
#    6315     # need to rewrap column in Series to apply key function
#    6316     if key is not None:
#    6317         # error: Incompatible types in assignment (expression has type
#    6318         # "Series", variable has type "ndarray")
#
# File /export/apps/CentOS7/anaconda/2022/envs/pycharmm-0.5/lib/python3.8/site-packages/pandas/core/generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'total_energy'
